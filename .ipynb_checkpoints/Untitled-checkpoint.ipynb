# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import heapq
import random

# %%
def parse_txt(file_path):
    graphs = []  
    current_matrix = []
    with open(file_path, 'r') as f:
        for line in f:
            line = line.strip()
            
            if line.startswith("Graph"):
                if current_matrix:
                    adj_matrix = np.array(current_matrix, dtype=int)
                    G = nx.from_numpy_array(adj_matrix)
                    for u, v in G.edges():
                        G[u][v]['weight'] = random.randint(1, 10) 
                    graphs.append(G)
                    current_matrix = [] 
            
            elif line:  
                    current_matrix.append([int(char) for char in line])
            
        if current_matrix:
            adj_matrix = np.array(current_matrix, dtype=int)
            G = nx.from_numpy_array(adj_matrix)
            for u, v in G.edges():
                G[u][v]['weight'] = random.randint(1, 10)
            graphs.append(G)
            
        return graphs

# %%
def visualize_graphs(graphs):
    i = 1  
    for graph in graphs:
        plt.figure(figsize=(6, 6))
        
        pos = nx.spring_layout(graph, seed=42) 
        
        nx.draw(graph, pos, with_labels=True, node_color='pink', edge_color='gray')
        
        edge_labels = nx.get_edge_attributes(graph, 'weight')
        
        nx.draw_networkx_edge_labels(graph, pos, edge_labels=edge_labels)
        
        plt.title(f"Graph {i}")
        
        plt.show()
        i += 1
        
graphs = parse_txt("graph_output.txt")
visualize_graphs(graphs)
# Out:
# ---------------------------------------------------------------------------
# NetworkXException                         Traceback (most recent call last)
# Cell In[4], line 20
#      17         i += 1
#      19 graphs = parse_txt("graph_output.txt")
# ---> 20 visualize_graphs(graphs)
#
# Cell In[4], line 6, in visualize_graphs(graphs)
#       3 for graph in graphs:
#       4     plt.figure(figsize=(6, 6))
# ----> 6     pos = nx.planar_layout(graph)
#       8     nx.draw(graph, pos, with_labels=True, node_color='pink', edge_color='gray')
#      10     edge_labels = nx.get_edge_attributes(graph, 'weight')
#
# File ~/anaconda3/lib/python3.11/site-packages/networkx/drawing/layout.py:941, in planar_layout(G, scale, center, dim)
#     939     is_planar, embedding = nx.check_planarity(G)
#     940     if not is_planar:
# --> 941         raise nx.NetworkXException("G is not planar.")
#     942 pos = nx.combinatorial_embedding_to_pos(embedding)
#     943 node_list = list(embedding)
#
# NetworkXException: G is not planar.

# %%
def prim_mst(G):
    
    start_node = list(G.nodes())[0]  
    visited = set([start_node])
    
    edges = [
        (G[start_node][dest]["weight"], start_node, dest)
        for dest in G[start_node]
    ]
    heapq.heapify(edges)  
    mst = []  
    
    while edges and len(visited) < len(G.nodes):
        weight, src, dest = heapq.heappop(edges)
        if dest in visited:
            continue
        visited.add(dest)
        mst.append((weight, src, dest))
        
        
        for neighbor, edge_attr in G[dest].items():
            if neighbor not in visited:
                edge_weight = edge_attr["weight"]
                heapq.heappush(edges, (edge_weight, dest, neighbor))
    
    return mst

# %%
for i, graph in enumerate(graphs):
    mst_edges = prim_mst(graph)
    print(f"MST for Graph {i + 1}:", mst_edges)
# Out:
# MST for Graph 1: [(3, 0, 2), (4, 2, 4), (4, 4, 3), (3, 3, 1)]
# MST for Graph 2: [(3, 0, 3), (4, 0, 4), (1, 4, 2), (5, 2, 1)]
# MST for Graph 3: [(1, 0, 1), (1, 0, 2), (1, 0, 3), (1, 0, 4)]

# %%
# Out:
# NetworkX MST for Graph 1:
# Edge (0, 2) with weight: 3
# Edge (1, 3) with weight: 3
# Edge (2, 4) with weight: 4
# Edge (3, 4) with weight: 4
#
#
# NetworkX MST for Graph 2:
# Edge (0, 3) with weight: 3
# Edge (0, 4) with weight: 4
# Edge (1, 2) with weight: 5
# Edge (2, 4) with weight: 1
#
#
# NetworkX MST for Graph 3:
# Edge (0, 1) with weight: 1
# Edge (0, 2) with weight: 1
# Edge (0, 3) with weight: 1
# Edge (0, 4) with weight: 1

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 custom_mst_set = set((min(u, v), max(u, v), weight) for u, v, weight in custom_mst_edges)
#       2 nx_mst_set = set((min(u, v), max(u, v), weight) for u, v, weight in nx_mst.edges(data='weight'))
#       3 assert custom_mst_set == nx_mst_set, "Edge sets do not match"
#
# NameError: name 'custom_mst_edges' is not defined
